# %%
import matplotlib.pyplot as plt

# %%
x1 = [2,4,6,8,10]
y1 = [1,3,5,7,9]

# %%
plt.plot(x1, y1, linestyle="solid", marker="o", color="r")
plt.ylabel("Y-Axis")
plt.xlabel("X-Axis")
plt.title("First Plot")
plt.savefig("myplot.png")
